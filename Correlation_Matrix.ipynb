# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def format_data(data,year,threshold):
    '''
    This function returns a dataset with countries as rows, and 
    indicators (e.g population, attendance rate, etc) as columns.
    The year parameter specifies which year that information comes from.
    (I noticed that 2010 and 2015 have a decent amount of data).
    Many of the countries don't have much data, so I included a threshold.
    If the threshold is 800, for instance, that means every country
    included in the dataset must have a non-empty value for at least 800 out
    of ~3600 attributes.
    
    '''
    country_names = data["Country Name"].unique()
    country_names = country_names[25:]
    country_names = country_names.tolist()
    countries = []
    for i in range(len(country_names)):
        d = data[data["Country Name"] == country_names[i]]
        if len(d[str(year)][d[str(year)]==d[str(year)]]) > threshold:
            countries.append(country_names[i])

    indicators = data["Indicator Name"].unique().tolist()

    indicator_list = []

    for i in countries:
        d = data[data["Country Name"] == i]
        valid_ind = d["Indicator Name"][d[str(year)]==d[str(year)]].tolist()
        for i in range(len(valid_ind)):
            indicator_list.append(valid_ind[i])
        indicator_set = set(indicator_list)
        indicator_list = list(indicator_set)

    index_list = []
    for i in indicator_list:
        index_list.append(indicators.index(i))

    data_subset = data[data["Country Name"].isin(countries)]
    curr_year = data_subset[str(year)]
    row_list = []
    for i in range(len(countries)):
        row = curr_year[i*len(indicators):(i+1)*len(indicators)]
        row = row.tolist()
        row_subset = []
        for i in index_list:
            row_subset.append(row[i])
        row_list.append(row_subset)

    df = pd.DataFrame(row_list)
    df.columns = indicator_list
    df.index = countries

    return df


directory = "./education-statistics/EdStatsData.csv"
data = pd.read_csv(directory,sep=",")

# %%
df = format_data(data,2010,800)
df
# Out:
#                                 UIS: Net attendance rate, lower secondary, rural, male (%)  \
# Albania                                                                       NaN
# Algeria                                                                       NaN
# Argentina                                                                     NaN
# Armenia                                                                       NaN
# Aruba                                                                         NaN
# Australia                                                                     NaN
# Austria                                                                       NaN
# Azerbaijan                                                                    NaN
# Bahamas, The                                                                  NaN
# Bahrain                                                                       NaN
# Bangladesh                                                                    NaN
# Barbados                                                                      NaN
# Belarus                                                                       NaN
# Belgium                                                                       NaN
# Belize                                                                        NaN
# Benin                                                                         NaN
# Bhutan                                                                  35.720615
# Bolivia                                                                       NaN
# Bosnia and Herzegovina                                                        NaN
# Brazil                                                                        NaN
# Brunei Darussalam                                                             NaN
# Bulgaria                                                                      NaN
# Burkina Faso                                                            11.555689
# Burundi                                                                  9.877707
# Cabo Verde                                                                    NaN
# Cambodia                                                                38.615204
# Cameroon                                                                      NaN
# Canada                                                                        NaN
# Central African Republic                                                      NaN
# Chad                                                                          NaN
# ...                                                                           ...
# St. Lucia                                                                     NaN
# St. Vincent and the Grenadines                                                NaN
# Sudan                                                                         NaN
# Suriname                                                                      NaN
# Swaziland                                                               23.782484
# Sweden                                                                        NaN
# Switzerland                                                                   NaN
# Syrian Arab Republic                                                          NaN
# Tajikistan                                                                    NaN
# Tanzania                                                                19.392361
# Thailand                                                                      NaN
# Timor-Leste                                                                   NaN
# Togo                                                                    29.841461
# Tonga                                                                         NaN
# Trinidad and Tobago                                                           NaN
# Tunisia                                                                       NaN
# Turkey                                                                        NaN
# Uganda                                                                        NaN
# Ukraine                                                                       NaN
# United Arab Emirates                                                          NaN
# United Kingdom                                                                NaN
# United States                                                                 NaN
# Uruguay                                                                       NaN
# Vanuatu                                                                       NaN
# Venezuela, RB                                                                 NaN
# Vietnam                                                                       NaN
# West Bank and Gaza                                                            NaN
# Yemen, Rep.                                                                   NaN
# Zambia                                                                        NaN
# Zimbabwe                                                                41.002377
#
#                                 MICS: Net attendance rate. Secondary. Rural  \
# Albania                                                                 NaN
# Algeria                                                                 NaN
# Argentina                                                               NaN
# Armenia                                                                 NaN
# Aruba                                                                   NaN
# Australia                                                               NaN
# Austria                                                                 NaN
# Azerbaijan                                                              NaN
# Bahamas, The                                                            NaN
# Bahrain                                                                 NaN
# Bangladesh                                                              NaN
# Barbados                                                                NaN
# Belarus                                                                 NaN
# Belgium                                                                 NaN
# Belize                                                                  NaN
# Benin                                                                   NaN
# Bhutan                                                            63.488064
# Bolivia                                                                 NaN
# Bosnia and Herzegovina                                                  NaN
# Brazil                                                                  NaN
# Brunei Darussalam                                                       NaN
# Bulgaria                                                                NaN
# Burkina Faso                                                            NaN
# Burundi                                                                 NaN
# Cabo Verde                                                              NaN
# Cambodia                                                                NaN
# Cameroon                                                                NaN
# Canada                                                                  NaN
# Central African Republic                                          14.113522
# Chad                                                                    NaN
# ...                                                                     ...
# St. Lucia                                                               NaN
# St. Vincent and the Grenadines                                          NaN
# Sudan                                                                   NaN
# Suriname                                                          47.901130
# Swaziland                                                         37.408035
# Sweden                                                                  NaN
# Switzerland                                                             NaN
# Syrian Arab Republic                                                    NaN
# Tajikistan                                                              NaN
# Tanzania                                                                NaN
# Thailand                                                                NaN
# Timor-Leste                                                             NaN
# Togo                                                                    NaN
# Tonga                                                                   NaN
# Trinidad and Tobago                                                     NaN
# Tunisia                                                                 NaN
# Turkey                                                                  NaN
# Uganda                                                                  NaN
# Ukraine                                                                 NaN
# United Arab Emirates                                                    NaN
# United Kingdom                                                          NaN
# United States                                                           NaN
# Uruguay                                                                 NaN
# Vanuatu                                                                 NaN
# Venezuela, RB                                                           NaN
# Vietnam                                                           95.719667
# West Bank and Gaza                                                      NaN
# Yemen, Rep.                                                             NaN
# Zambia                                                                  NaN
# Zimbabwe                                                                NaN
#
#                                 Population, age 16, male  \
# Albania                                          30436.0
# Algeria                                         356469.0
# Argentina                                       352999.0
# Armenia                                          26269.0
# Aruba                                              732.0
# Australia                                       147539.0
# Austria                                          50446.0
# Azerbaijan                                       88120.0
# Bahamas, The                                      3150.0
# Bahrain                                           6552.0
# Bangladesh                                     1788359.0
# Barbados                                          1984.0
# Belarus                                          58137.0
# Belgium                                          64127.0
# Belize                                            3358.0
# Benin                                           111618.0
# Bhutan                                            7768.0
# Bolivia                                         112334.0
# Bosnia and Herzegovina                           24362.0
# Brazil                                         1672344.0
# Brunei Darussalam                                 3636.0
# Bulgaria                                         38812.0
# Burkina Faso                                    186282.0
# Burundi                                         103871.0
# Cabo Verde                                        6348.0
# Cambodia                                        189258.0
# Cameroon                                        224055.0
# Canada                                          226348.0
# Central African Republic                         52928.0
# Chad                                            130292.0
# ...                                                  ...
# St. Lucia                                         1598.0
# St. Vincent and the Grenadines                    1108.0
# Sudan                                           466536.0
# Suriname                                          4086.0
# Swaziland                                        15122.0
# Sweden                                           63008.0
# Switzerland                                      49081.0
# Syrian Arab Republic                            222029.0
# Tajikistan                                       86410.0
# Tanzania                                        474162.0
# Thailand                                        477966.0
# Timor-Leste                                      14170.0
# Togo                                             79556.0
# Tonga                                             1315.0
# Trinidad and Tobago                              10224.0
# Tunisia                                          97969.0
# Turkey                                          712931.0
# Uganda                                          402536.0
# Ukraine                                         266926.0
# United Arab Emirates                             31227.0
# United Kingdom                                  397312.0
# United States                                  2294144.0
# Uruguay                                          27324.0
# Vanuatu                                           2804.0
# Venezuela, RB                                   278260.0
# Vietnam                                         928260.0
# West Bank and Gaza                               49888.0
# Yemen, Rep.                                     303074.0
# Zambia                                          150748.0
# Zimbabwe                                        172042.0
#
#                                 Population, ages 10-16, total  \
# Albania                                              383677.0
# Algeria                                             4348406.0
# Argentina                                           4816935.0
# Armenia                                              290625.0
# Aruba                                                 10276.0
# Australia                                           1914783.0
# Austria                                              634870.0
# Azerbaijan                                          1010894.0
# Bahamas, The                                          42928.0
# Bahrain                                               87203.0
# Bangladesh                                         24426990.0
# Barbados                                              25722.0
# Belarus                                              691480.0
# Belgium                                              842230.0
# Belize                                                48262.0
# Benin                                               1663882.0
# Bhutan                                                99877.0
# Bolivia                                             1578463.0
# Bosnia and Herzegovina                               343658.0
# Brazil                                             23935881.0
# Brunei Darussalam                                     48957.0
# Bulgaria                                             470709.0
# Burkina Faso                                        2801448.0
# Burundi                                             1524079.0
# Cabo Verde                                            89413.0
# Cambodia                                            2422980.0
# Cameroon                                            3228479.0
# Canada                                              2797514.0
# Central African Republic                             796360.0
# Chad                                                2022087.0
# ...                                                       ...
# St. Lucia                                             20361.0
# St. Vincent and the Grenadines                        14925.0
# Sudan                                               6863038.0
# Suriname                                              61316.0
# Swaziland                                            204901.0
# Sweden                                               721785.0
# Switzerland                                          619353.0
# Syrian Arab Republic                                3150608.0
# Tajikistan                                          1185409.0
# Tanzania                                            7319179.0
# Thailand                                            6336339.0
# Timor-Leste                                          220043.0
# Togo                                                1206026.0
# Tonga                                                 17470.0
# Trinidad and Tobago                                  132071.0
# Tunisia                                             1203521.0
# Turkey                                              9813783.0
# Uganda                                              6195923.0
# Ukraine                                             3110125.0
# United Arab Emirates                                 382669.0
# United Kingdom                                      5104922.0
# United States                                      29775689.0
# Uruguay                                              367407.0
# Vanuatu                                               39607.0
# Venezuela, RB                                       3864502.0
# Vietnam                                            11380240.0
# West Bank and Gaza                                   787395.0
# Yemen, Rep.                                         4375634.0
# Zambia                                              2317308.0
# Zimbabwe                                            2381023.0
#
#                                 Population, ages 3-5, male  \
# Albania                                            76840.0
# Algeria                                          1025279.0
# Argentina                                        1021720.0
# Armenia                                            53100.0
# Aruba                                               2200.0
# Australia                                         396347.0
# Austria                                           122140.0
# Azerbaijan                                        177620.0
# Bahamas, The                                        8256.0
# Bahrain                                            19951.0
# Bangladesh                                       5823195.0
# Barbados                                            5002.0
# Belarus                                           141418.0
# Belgium                                           172317.0
# Belize                                             10897.0
# Benin                                             466891.0
# Bhutan                                             17845.0
# Bolivia                                           379106.0
# Bosnia and Herzegovina                             55093.0
# Brazil                                           5542898.0
# Brunei Darussalam                                  12579.0
# Bulgaria                                          106491.0
# Burkina Faso                                      805707.0
# Burundi                                           469478.0
# Cabo Verde                                         22601.0
# Cambodia                                          520215.0
# Cameroon                                          860470.0
# Canada                                            540604.0
# Central African Republic                          197655.0
# Chad                                              593997.0
# ...                                                    ...
# St. Lucia                                           4650.0
# St. Vincent and the Grenadines                      3599.0
# Sudan                                            1674590.0
# Suriname                                           13281.0
# Swaziland                                          43518.0
# Sweden                                            162052.0
# Switzerland                                       109507.0
# Syrian Arab Republic                              790619.0
# Tajikistan                                        258896.0
# Tanzania                                         2138270.0
# Thailand                                         1373263.0
# Timor-Leste                                        61172.0
# Togo                                              318674.0
# Tonga                                               3574.0
# Trinidad and Tobago                                28811.0
# Tunisia                                           258752.0
# Turkey                                           2003382.0
# Uganda                                           1830396.0
# Ukraine                                           627934.0
# United Arab Emirates                              104877.0
# United Kingdom                                   1076018.0
# United States                                    6529463.0
# Uruguay                                            76267.0
# Vanuatu                                             9582.0
# Venezuela, RB                                     890803.0
# Vietnam                                          2518675.0
# West Bank and Gaza                                212453.0
# Yemen, Rep.                                      1152845.0
# Zambia                                            601316.0
# Zimbabwe                                          504341.0
#
#                                 Enrolment in early childhood education, female (number)  \
# Albania                                                                   35340.0
# Algeria                                                                       NaN
# Argentina                                                                781251.0
# Armenia                                                                       NaN
# Aruba                                                                      1352.0
# Australia                                                                105372.0
# Austria                                                                  116811.0
# Azerbaijan                                                                42641.0
# Bahamas, The                                                                  NaN
# Bahrain                                                                   13356.0
# Bangladesh                                                               600114.0
# Barbados                                                                      NaN
# Belarus                                                                  163064.0
# Belgium                                                                  211330.0
# Belize                                                                     3371.0
# Benin                                                                     49224.0
# Bhutan                                                                      313.0
# Bolivia                                                                  110806.0
# Bosnia and Herzegovina                                                        NaN
# Brazil                                                                        NaN
# Brunei Darussalam                                                          6357.0
# Bulgaria                                                                 105093.0
# Burkina Faso                                                                  NaN
# Burundi                                                                   27522.0
# Cabo Verde                                                                10773.0
# Cambodia                                                                  93742.0
# Cameroon                                                                 158883.0
# Canada                                                                        NaN
# Central African Republic                                                      NaN
# Chad                                                                          NaN
# ...                                                                           ...
# St. Lucia                                                                  1650.0
# St. Vincent and the Grenadines                                                NaN
# Sudan                                                                    331894.0
# Suriname                                                                      NaN
# Swaziland                                                                 10452.0
# Sweden                                                                   193994.0
# Switzerland                                                               71625.0
# Syrian Arab Republic                                                      70642.0
# Tajikistan                                                                25843.0
# Tanzania                                                                 463837.0
# Thailand                                                                1365749.0
# Timor-Leste                                                                   NaN
# Togo                                                                      21684.0
# Tonga                                                                         NaN
# Trinidad and Tobago                                                           NaN
# Tunisia                                                                       NaN
# Turkey                                                                        NaN
# Uganda                                                                        NaN
# Ukraine                                                                  581272.0
# United Arab Emirates                                                      60713.0
# United Kingdom                                                                NaN
# United States                                                                 NaN
# Uruguay                                                                   64396.0
# Vanuatu                                                                    5489.0
# Venezuela, RB                                                            793461.0
# Vietnam                                                                 1374341.0
# West Bank and Gaza                                                        43984.0
# Yemen, Rep.                                                               11923.0
# Zambia                                                                        NaN
# Zimbabwe                                                                      NaN
#
#                                 Percentage of repeaters in Grade 6 of lower secondary general education, male (%)  \
# Albania                                                                       NaN
# Algeria                                                                       NaN
# Argentina                                                                     NaN
# Armenia                                                                       NaN
# Aruba                                                                         NaN
# Australia                                                                     NaN
# Austria                                                                       NaN
# Azerbaijan                                                                    NaN
# Bahamas, The                                                                  NaN
# Bahrain                                                                       NaN
# Bangladesh                                                                    NaN
# Barbados                                                                      NaN
# Belarus                                                                       NaN
# Belgium                                                                       NaN
# Belize                                                                        NaN
# Benin                                                                         NaN
# Bhutan                                                                        NaN
# Bolivia                                                                       NaN
# Bosnia and Herzegovina                                                        NaN
# Brazil                                                                        NaN
# Brunei Darussalam                                                             NaN
# Bulgaria                                                                      NaN
# Burkina Faso                                                                  NaN
# Burundi                                                                       NaN
# Cabo Verde                                                                    NaN
# Cambodia                                                                      NaN
# Cameroon                                                                      NaN
# Canada                                                                        NaN
# Central African Republic                                                      NaN
# Chad                                                                          NaN
# ...                                                                           ...
# St. Lucia                                                                     NaN
# St. Vincent and the Grenadines                                                NaN
# Sudan                                                                         NaN
# Suriname                                                                      NaN
# Swaziland                                                                     NaN
# Sweden                                                                        NaN
# Switzerland                                                                   NaN
# Syrian Arab Republic                                                          NaN
# Tajikistan                                                                    NaN
# Tanzania                                                                      NaN
# Thailand                                                                      NaN
# Timor-Leste                                                                   NaN
# Togo                                                                          NaN
# Tonga                                                                         NaN
# Trinidad and Tobago                                                           NaN
# Tunisia                                                                       NaN
# Turkey                                                                        NaN
# Uganda                                                                        NaN
# Ukraine                                                                       NaN
# United Arab Emirates                                                          NaN
# United Kingdom                                                                NaN
# United States                                                                 NaN
# Uruguay                                                                       NaN
# Vanuatu                                                                       NaN
# Venezuela, RB                                                                 NaN
# Vietnam                                                                       NaN
# West Bank and Gaza                                                        2.09785
# Yemen, Rep.                                                                   NaN
# Zambia                                                                        NaN
# Zimbabwe                                                                      NaN
#
#                                 Wittgenstein Projection: Percentage of the population age 40-64 by highest level of educational attainment. No Education. Male  \
# Albania                                                                      0.01
# Algeria                                                                      0.20
# Argentina                                                                    0.03
# Armenia                                                                      0.00
# Aruba                                                                        0.07
# Australia                                                                    0.01
# Austria                                                                      0.00
# Azerbaijan                                                                   0.01
# Bahamas, The                                                                 0.02
# Bahrain                                                                      0.12
# Bangladesh                                                                   0.43
# Barbados                                                                      NaN
# Belarus                                                                      0.00
# Belgium                                                                      0.03
# Belize                                                                       0.10
# Benin                                                                        0.49
# Bhutan                                                                       0.57
# Bolivia                                                                      0.05
# Bosnia and Herzegovina                                                       0.02
# Brazil                                                                       0.12
# Brunei Darussalam                                                             NaN
# Bulgaria                                                                     0.01
# Burkina Faso                                                                 0.80
# Burundi                                                                      0.59
# Cabo Verde                                                                   0.11
# Cambodia                                                                     0.19
# Cameroon                                                                     0.22
# Canada                                                                       0.01
# Central African Republic                                                     0.25
# Chad                                                                         0.66
# ...                                                                           ...
# St. Lucia                                                                    0.03
# St. Vincent and the Grenadines                                               0.01
# Sudan                                                                        0.65
# Suriname                                                                     0.00
# Swaziland                                                                    0.19
# Sweden                                                                       0.00
# Switzerland                                                                  0.00
# Syrian Arab Republic                                                         0.15
# Tajikistan                                                                   0.02
# Tanzania                                                                     0.18
# Thailand                                                                     0.03
# Timor-Leste                                                                  0.51
# Togo                                                                          NaN
# Tonga                                                                        0.01
# Trinidad and Tobago                                                          0.02
# Tunisia                                                                      0.18
# Turkey                                                                       0.04
# Uganda                                                                       0.19
# Ukraine                                                                      0.00
# United Arab Emirates                                                         0.12
# United Kingdom                                                               0.01
# United States                                                                0.01
# Uruguay                                                                      0.01
# Vanuatu                                                                      0.18
# Venezuela, RB                                                                0.07
# Vietnam                                                                      0.03
# West Bank and Gaza                                                           0.07
# Yemen, Rep.                                                                   NaN
# Zambia                                                                       0.07
# Zimbabwe                                                                     0.06
#
#                                 UIS: Net attendance rate, primary, poorest quintile, gender parity index (GPI)  \
# Albania                                                                       NaN
# Algeria                                                                       NaN
# Argentina                                                                     NaN
# Armenia                                                                       NaN
# Aruba                                                                         NaN
# Australia                                                                     NaN
# Austria                                                                       NaN
# Azerbaijan                                                                    NaN
# Bahamas, The                                                                  NaN
# Bahrain                                                                       NaN
# Bangladesh                                                                    NaN
# Barbados                                                                      NaN
# Belarus                                                                       NaN
# Belgium                                                                       NaN
# Belize                                                                        NaN
# Benin                                                                         NaN
# Bhutan                                                                   0.955960
# Bolivia                                                                       NaN
# Bosnia and Herzegovina                                                        NaN
# Brazil                                                                        NaN
# Brunei Darussalam                                                             NaN
# Bulgaria                                                                      NaN
# ...
# Switzerland                                                                  0.66
# Syrian Arab Republic                                                         0.19
# Tajikistan                                                                   0.75
# Tanzania                                                                     0.03
# Thailand                                                                     0.37
# Timor-Leste                                                                  0.29
# Togo                                                                          NaN
# Tonga                                                                        0.22
# Trinidad and Tobago                                                          0.31
# Tunisia                                                                      0.32
# Turkey                                                                       0.47
# Uganda                                                                       0.06
# Ukraine                                                                      0.83
# United Arab Emirates                                                         0.43
# United Kingdom                                                               0.33
# United States                                                                0.71
# Uruguay                                                                      0.22
# Vanuatu                                                                      0.18
# Venezuela, RB                                                                0.24
# Vietnam                                                                      0.25
# West Bank and Gaza                                                           0.45
# Yemen, Rep.                                                                   NaN
# Zambia                                                                       0.20
# Zimbabwe                                                                     0.60
#
#                                 Gross enrolment ratio, secondary, gender parity index (GPI)  \
# Albania                                                                   0.99040
# Algeria                                                                   1.03451
# Argentina                                                                 1.09787
# Armenia                                                                       NaN
# Aruba                                                                     1.05126
# Australia                                                                 0.96963
# Austria                                                                   0.96006
# Azerbaijan                                                                    NaN
# Bahamas, The                                                              1.05371
# Bahrain                                                                   1.01361
# Bangladesh                                                                1.12295
# Barbados                                                                  1.00495
# Belarus                                                                   0.96800
# Belgium                                                                   0.97120
# Belize                                                                    1.07892
# Benin                                                                         NaN
# Bhutan                                                                    1.01641
# Bolivia                                                                   0.98767
# Bosnia and Herzegovina                                                        NaN
# Brazil                                                                        NaN
# Brunei Darussalam                                                         1.00796
# Bulgaria                                                                  0.95557
# Burkina Faso                                                              0.76379
# Burundi                                                                   0.68826
# Cabo Verde                                                                1.17600
# Cambodia                                                                      NaN
# Cameroon                                                                      NaN
# Canada                                                                    0.97640
# Central African Republic                                                      NaN
# Chad                                                                      0.42314
# ...                                                                           ...
# St. Lucia                                                                 0.98850
# St. Vincent and the Grenadines                                            1.02414
# Sudan                                                                     0.86625
# Suriname                                                                  1.27682
# Swaziland                                                                 0.99948
# Sweden                                                                    0.98961
# Switzerland                                                               0.97043
# Syrian Arab Republic                                                      1.00186
# Tajikistan                                                                0.86996
# Tanzania                                                                  0.79053
# Thailand                                                                  1.06066
# Timor-Leste                                                               1.00651
# Togo                                                                          NaN
# Tonga                                                                     1.06751
# Trinidad and Tobago                                                           NaN
# Tunisia                                                                   1.06723
# Turkey                                                                    0.91599
# Uganda                                                                        NaN
# Ukraine                                                                   0.97590
# United Arab Emirates                                                          NaN
# United Kingdom                                                            0.99626
# United States                                                             1.01777
# Uruguay                                                                   1.13702
# Vanuatu                                                                   0.99789
# Venezuela, RB                                                             1.09618
# Vietnam                                                                       NaN
# West Bank and Gaza                                                        1.07950
# Yemen, Rep.                                                               0.62170
# Zambia                                                                        NaN
# Zimbabwe                                                                      NaN
#
#                                 Drop-out rate from Grade 1 of primary education, both sexes (%)
# Albania                                                                  0.960790
# Algeria                                                                  0.722020
# Argentina                                                                2.190120
# Armenia                                                                  1.995270
# Aruba                                                                         NaN
# Australia                                                                     NaN
# Austria                                                                  0.248300
# Azerbaijan                                                               0.528810
# Bahamas, The                                                                  NaN
# Bahrain                                                                  0.435420
# Bangladesh                                                                    NaN
# Barbados                                                                 2.065880
# Belarus                                                                  0.775620
# Belgium                                                                       NaN
# Belize                                                                   2.885850
# Benin                                                                   15.286070
# Bhutan                                                                   2.773080
# Bolivia                                                                  3.180810
# Bosnia and Herzegovina                                                   0.376360
# Brazil                                                                        NaN
# Brunei Darussalam                                                        0.272830
# Bulgaria                                                                 1.316600
# Burkina Faso                                                                  NaN
# Burundi                                                                 14.044450
# Cabo Verde                                                               1.276370
# Cambodia                                                                 9.082010
# Cameroon                                                                16.399509
# Canada                                                                        NaN
# Central African Republic                                                14.594500
# Chad                                                                    15.678380
# ...                                                                           ...
# St. Lucia                                                                1.437810
# St. Vincent and the Grenadines                                           5.478780
# Sudan                                                                         NaN
# Suriname                                                                      NaN
# Swaziland                                                                6.997340
# Sweden                                                                   1.088120
# Switzerland                                                                   NaN
# Syrian Arab Republic                                                     1.728880
# Tajikistan                                                               0.318820
# Tanzania                                                                      NaN
# Thailand                                                                      NaN
# Timor-Leste                                                              4.470250
# Togo                                                                    16.400240
# Tonga                                                                         NaN
# Trinidad and Tobago                                                           NaN
# Tunisia                                                                       NaN
# Turkey                                                                   4.121180
# Uganda                                                                  30.371201
# Ukraine                                                                  0.820200
# United Arab Emirates                                                     4.191080
# United Kingdom                                                                NaN
# United States                                                                 NaN
# Uruguay                                                                       NaN
# Vanuatu                                                                       NaN
# Venezuela, RB                                                            0.817550
# Vietnam                                                                  1.093680
# West Bank and Gaza                                                       1.266600
# Yemen, Rep.                                                                   NaN
# Zambia                                                                        NaN
# Zimbabwe                                                                      NaN
#
# [163 rows x 2568 columns]

# %%
#threshold - all attributes in the correlation matrix mus have at least this number of values
def correlation_matrix(data,threshold):
    drop = [i for i in data.columns if len(data[i][~data[i].isnull()]) < threshold]
    filtered_df = data.drop(drop,axis=1)
    corrmat = filtered_df.corr()
    return corrmat

corrmat = correlation_matrix(df,50)
